# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
import yfinance as yf

df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')
df = df[['Close']]
# Out:
# C:\Users\Marcos Simoneli\AppData\Local\Temp\ipykernel_36156\3896639056.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('AAPL', start='2015-01-01', end='2023-12-31')
# [*********************100%***********************]  1 of 1 completed

# %%
# Normalização dos dados
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# %%
# Função para criar janelas de dados sequenciais
def create_dataset(data, time_step=90):
    X, y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i - time_step:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
# Dividir dados em treino e validação (80% treino, 20% validação)
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size - 60:]  # pegar os 60 passos anteriores

X_train, y_train = create_dataset(train_data)
X_test, y_test = create_dataset(test_data)

# %%
print(X_test)
# Out:
# [[0.88249205 0.84323625 0.83699108 ... 0.8118542  0.78600406 0.79208981]
#  [0.84323625 0.83699108 0.82924042 ... 0.78600406 0.79208981 0.75814409]
#  [0.83699108 0.82924042 0.84730688 ... 0.79208981 0.75814409 0.75686   ]
#  ...
#  [0.86549323 0.87309686 0.88092588 ... 0.98065543 0.97456448 0.97146266]
#  [0.87309686 0.88092588 0.90283585 ... 0.97456448 0.97146266 0.97202647]
#  [0.88092588 0.90283585 0.87613844 ... 0.97146266 0.97202647 0.9744517 ]]

# %%
# Remodelar para LSTM [amostras, time steps, features]
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.1))
model.add(Dense(1))
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')
# Out:
# c:\Users\Marcos Simoneli\OneDrive\Documentos\Machine Learning\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(X_train, y_train, epochs=40, batch_size=16, validation_split=0.1)

predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions.reshape(-1, 1))
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))
# Out:
# Epoch 1/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0120 - val_loss: 0.0015
# Epoch 2/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 7.0077e-04 - val_loss: 0.0011
# Epoch 3/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 6.8874e-04 - val_loss: 0.0014
# Epoch 4/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 7.4914e-04 - val_loss: 0.0021
# Epoch 5/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.0572e-04 - val_loss: 0.0065
# Epoch 6/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.7689e-04 - val_loss: 7.9254e-04
# Epoch 7/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.2790e-04 - val_loss: 0.0021
# Epoch 8/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.5922e-04 - val_loss: 9.9379e-04
# Epoch 9/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 4.6501e-04 - val_loss: 0.0017
# Epoch 10/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.9977e-04 - val_loss: 0.0017
# Epoch 11/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.6505e-04 - val_loss: 0.0014
# Epoch 12/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.1978e-04 - val_loss: 0.0018
# Epoch 13/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 6.0161e-04 - val_loss: 5.9628e-04
# Epoch 14/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.8843e-04 - val_loss: 5.6861e-04
# Epoch 15/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.9373e-04 - val_loss: 6.4004e-04
# Epoch 16/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.2326e-04 - val_loss: 5.8171e-04
# Epoch 17/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.0561e-04 - val_loss: 0.0015
# Epoch 18/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.2767e-04 - val_loss: 0.0017
# Epoch 19/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.7679e-04 - val_loss: 0.0019
# Epoch 20/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.2478e-04 - val_loss: 9.0751e-04
# Epoch 21/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 4.0186e-04 - val_loss: 0.0018
# Epoch 22/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 4.2261e-04 - val_loss: 8.2291e-04
# Epoch 23/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3958e-04 - val_loss: 8.6652e-04
# Epoch 24/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.8917e-04 - val_loss: 6.2017e-04
# Epoch 25/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.0471e-04 - val_loss: 4.7507e-04
# Epoch 26/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.2796e-04 - val_loss: 5.7350e-04
# Epoch 27/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.4348e-04 - val_loss: 4.7633e-04
# Epoch 28/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.5216e-04 - val_loss: 9.4553e-04
# Epoch 29/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.2579e-04 - val_loss: 6.3865e-04
# Epoch 30/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9756e-04 - val_loss: 4.5504e-04
# Epoch 31/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.3736e-04 - val_loss: 0.0015
# Epoch 32/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.7475e-04 - val_loss: 4.8965e-04
# Epoch 33/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.0359e-04 - val_loss: 8.6470e-04
# Epoch 34/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9542e-04 - val_loss: 0.0011
# Epoch 35/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.7397e-04 - val_loss: 0.0010
# Epoch 36/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8560e-04 - val_loss: 4.4988e-04
# Epoch 37/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8124e-04 - val_loss: 0.0014
# Epoch 38/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.6729e-04 - val_loss: 0.0035
# Epoch 39/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.8635e-04 - val_loss: 0.0035
# Epoch 40/40
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.6335e-04 - val_loss: 4.0247e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
# Métricas
mae = mean_absolute_error(real_prices, predictions)
rmse = np.sqrt(mean_squared_error(real_prices, predictions))
mape = mean_absolute_percentage_error(real_prices, predictions)

print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAPE: {mape:.4%}")
# Out:
# MAE: 3.6772
# RMSE: 4.4447
# MAPE: 2.2870%

# %%
plt.figure(figsize=(12,6))
plt.plot(real_prices, label='Real')
plt.plot(predictions, label='Predito')
plt.title('Previsão de Preço de Ações com LSTM')
plt.xlabel('Dias')
plt.ylabel('Preço')
plt.legend()
plt.show()

print("")

model.save('modelo_lstm_acao.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0
